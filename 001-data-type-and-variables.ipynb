# %% [markdown]
# **First Program**

# %%
# %%writefile helloworld.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#     cout<<"Namaste Duniya";
#     return 0;
# }
# Out:
# Overwriting helloworld.cpp

# %%
! g++ helloworld.cpp -o helloProgram
! ./helloProgram
# Out:
# Namaste Duniya

# %% [markdown]
# **Data Type**

# %%
# %%writefile datatype.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#     int a = 123;
#     cout<<a<<endl;
#     int size1 = sizeof(a);
#     cout<<size1<<endl;
#
#     char b = 'v';
#     cout<<b<<endl;
#     int size2 = sizeof(b);
#     cout<<size2<<endl;
#
#     bool bl = true;
#     cout<<bl<<endl;
#     int size3 = sizeof(bl);
#     cout<<size3<<endl;
#
#     float f = 1.2;
#     cout<<f<<endl;
#     int size4 = sizeof(f);
#     cout<<size4<<endl;
#
#     double d = 1.234567;
#     cout<<d<<endl;
#     int size5 = sizeof(d);
#     cout<<size5<<endl;
# }
# Out:
# Overwriting datatype.cpp

# %%
! g++ datatype.cpp -o datatype
! ./datatype
# Out:
# 123
# 4
# v
# 1
# 1
# 1
# 1.2
# 4
# 1.23457
# 8

# %% [markdown]
# **Type Casting**

# %%
# %%writefile typecast.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#     int a = 'a';
#     cout<<a<<endl;
#
#     char ch = 98;
#     cout<<ch<<endl;
#
#     return 0;
# }
# Out:
# Overwriting typecast.cpp

# %%
! g++ typecast.cpp -o typecast
! ./typecast
# Out:
# 97
# b

# %% [markdown]
# **Unsigned Int**

# %%
# %%writefile unsigned.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#     unsigned int a1 = 112;
#     cout<<a1<<endl;
#
#     unsigned int a2 = -112;
#     cout<<a2<<endl;
#
#     return 0;
# }
# Out:
# Overwriting unsigned.cpp

# %%
! g++ unsigned.cpp -o unsigned
! ./unsigned
# Out:
# 112
# 4294967184

# %% [markdown]
# **Operator**

# %%
# %%writefile operator.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#     float a = float(2)/5;
#     cout<<a<<endl;
#     return 0;
# }
# Out:
# Overwriting operator.cpp

# %%
! g++ operator.cpp -o operator
! ./operator
# Out:
# 0.4
