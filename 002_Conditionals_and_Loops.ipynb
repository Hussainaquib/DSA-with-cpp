# %% [markdown]
# # **if else Condition**

# %% [markdown]
# **Find number is negative, positive or zero**

# %%
# %%writefile condition1.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#   int n;
#   cin >> n;
#   if (n>0){
#     cout << "positive";
#   }
#   else if (n<0){
#     cout << "negative";
#   }
#   else{
#     cout << "zero";
#   }
# }
# Out:
# Writing condition1.cpp

# %%
! g++ condition1.cpp -o condition1
! ./condition1
# Out:
# 6
# positive

# %% [markdown]
# **Which on is greater**

# %%
# %%writefile condition2.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#   int a,b;
#   cin >> a >> b;
#   if (a>b){
#     cout << "a is greater";
#   }
#   else{
#     cout << "b is greater";
#   }
# }
# Out:
# Writing condition2.cpp

# %%
! g++ condition2.cpp -o condition2
! ./condition2
# Out:
# 2
# 1
# a is greater

# %% [markdown]
# **Print "lowwer case" if char is between a-z, print "upper case" if char is between A-Z, else in between 0-9 print "numeric"**

# %%
# %%writefile condition3.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#   char c;
#   cout<<"Enter a character: ";
#   cin>>c;
#   if (c>='a' && c<='z'){
#     cout<<"lower case";
#   }
#   else if (c>='A' && c<='Z'){
#     cout<<"upper case";
#   }
#   else{
#     cout<<"numeric";
#   }
# }
# Out:
# Writing condition3.cpp

# %%
! g++ condition3.cpp -o condition3
! ./condition3
# Out:
# Enter a character: 8
# numeric

# %% [markdown]
# # **Loops**

# %% [markdown]
# **Print number from 1 to n**

# %%
# %%writefile loop1.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#   int n;
#   cin >>n;
#   int i=1;
#   while (i<=n){
#     cout << i << " ";
#     i++;
#   }
# }
# Out:
# Overwriting loop1.cpp

# %%
! g++ loop1.cpp -o loop1
! ./loop1
# Out:
# 8
# 1 2 3 4 5 6 7 8

# %% [markdown]
# **Sum of number from 1 to n**

# %%
# %%writefile loop2.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#   int n;
#   int sum = 0;
#   cin >>n;
#   int i=1;
#   while (i<=n){
#     sum+=i;
#     i++;
#   }
#   cout<<sum;
# }
# Out:
# Overwriting loop2.cpp

# %%
! g++ loop2.cpp -o loop2
! ./loop2
# Out:
# 15
# 120

# %% [markdown]
# **Sum of even number from 1 to n**

# %%
# %%writefile loop3.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#   int n;
#   cin >>n;
#   int sum = 0;
#   int i=1;
#   while (i<=n){
#     if (i%2==0){
#       sum+=i;
#     }
#     i++;
#   }
#   cout<<sum;
# }
# Out:
# Overwriting loop3.cpp

# %%
! g++ loop3.cpp -o loop3
! ./loop3
# Out:
# 8
# 20

# %% [markdown]
# **Feranhite to celcious conversion**

# %%
# %%writefile loop4.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#   int f;
#   cin >>f;
#   int c;
#   c = (f-32)*5/9;
#   cout<<c;
# }
# Out:
# Overwriting loop4.cpp

# %%
! g++ loop4.cpp -o loop4
! ./loop4
# Out:
# 55
# 12

# %% [markdown]
# **Check number n is prime or not**

# %%
# %%writefile loop5.cpp
#
# #include<iostream>
# using namespace std;
# int main(){
#   int n;
#   cin >>n;
#   int i=2;
#   while (i<n){
#     if (n%i==0){
#       cout<<"not prime";
#       return 0;
#     }
#     i++;
#   }
#   cout<<"prime";
# }
# Out:
# Overwriting loop5.cpp

# %%
! g++ loop5.cpp -o loop5
! ./loop5
# Out:
# 9
# not prime
